# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("./Fuel_Consumption_2000-2022.csv")
data
# Out:
#        YEAR   MAKE        MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0      2000  ACURA        1.6EL        COMPACT          1.6          4
# 1      2000  ACURA        1.6EL        COMPACT          1.6          4
# 2      2000  ACURA        3.2TL       MID-SIZE          3.2          6
# 3      2000  ACURA        3.5RL       MID-SIZE          3.5          6
# 4      2000  ACURA      INTEGRA     SUBCOMPACT          1.8          4
# ...     ...    ...          ...            ...          ...        ...
# 22551  2022  VOLVO  XC40 T5 AWD     SUV: SMALL          2.0          4
# 22552  2022  VOLVO  XC60 B5 AWD     SUV: SMALL          2.0          4
# 22553  2022  VOLVO  XC60 B6 AWD     SUV: SMALL          2.0          4
# 22554  2022  VOLVO  XC90 T5 AWD  SUV: STANDARD          2.0          4
# 22555  2022  VOLVO  XC90 T6 AWD  SUV: STANDARD          2.0          4
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 KM)  COMB (L/100 KM)  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22556 entries, 0 to 22555
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              22556 non-null  int64
#  1   MAKE              22556 non-null  object
#  2   MODEL             22556 non-null  object
#  3   VEHICLE CLASS     22556 non-null  object
#  4   ENGINE SIZE       22556 non-null  float64
#  5   CYLINDERS         22556 non-null  int64
#  6   TRANSMISSION      22556 non-null  object
#  7   FUEL              22556 non-null  object
#  8   FUEL CONSUMPTION  22556 non-null  float64
#  9   HWY (L/100 KM)    22556 non-null  float64
#  10  COMB (L/100 KM)   22556 non-null  float64
#  11  COMB (MPG)        22556 non-null  int64
#  12  EMISSIONS         22556 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 2.2+ MB

# %%
data["MAKE"]
# Out:
# 0        ACURA
# 1        ACURA
# 2        ACURA
# 3        ACURA
# 4        ACURA
#          ...
# 22551    VOLVO
# 22552    VOLVO
# 22553    VOLVO
# 22554    VOLVO
# 22555    VOLVO
# Name: MAKE, Length: 22556, dtype: object

# %%
# selezionare più colonne

data[["MAKE", "MODEL", "YEAR"]]
# Out:
#         MAKE        MODEL  YEAR
# 0      ACURA        1.6EL  2000
# 1      ACURA        1.6EL  2000
# 2      ACURA        3.2TL  2000
# 3      ACURA        3.5RL  2000
# 4      ACURA      INTEGRA  2000
# ...      ...          ...   ...
# 22551  VOLVO  XC40 T5 AWD  2022
# 22552  VOLVO  XC60 B5 AWD  2022
# 22553  VOLVO  XC60 B6 AWD  2022
# 22554  VOLVO  XC90 T5 AWD  2022
# 22555  VOLVO  XC90 T6 AWD  2022
#
# [22556 rows x 3 columns]

# %%
data.iloc[0:5]
# Out:
#    YEAR   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 0  2000  ACURA    1.6EL       COMPACT          1.6          4           A4
# 1  2000  ACURA    1.6EL       COMPACT          1.6          4           M5
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2          6          AS5
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5          6           A4
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           A4
#
#   FUEL  FUEL CONSUMPTION  HWY (L/100 KM)  COMB (L/100 KM)  COMB (MPG)  \
# 0    X               9.2             6.7              8.1          35
# 1    X               8.5             6.5              7.6          37
# 2    Z              12.2             7.4             10.0          28
# 3    Z              13.4             9.2             11.5          25
# 4    X              10.0             7.0              8.6          33
#
#    EMISSIONS
# 0        186
# 1        175
# 2        230
# 3        264
# 4        198

# %%
data["MAKE"].value_counts()
# Out:
# MAKE
# CHEVROLET        2130
# FORD             1724
# BMW              1490
# GMC              1357
# MERCEDES-BENZ    1276
# TOYOTA           1001
# PORSCHE           988
# DODGE             925
# AUDI              805
# NISSAN            764
# VOLKSWAGEN        701
# MAZDA             602
# HYUNDAI           561
# HONDA             561
# JEEP              544
# KIA               532
# SUBARU            520
# VOLVO             515
# LEXUS             460
# CADILLAC          434
# CHRYSLER          425
# MINI              406
# JAGUAR            364
# MITSUBISHI        322
# INFINITI          280
# BUICK             273
# PONTIAC           253
# ACURA             247
# LINCOLN           225
# SUZUKI            199
# SAAB              190
# LAND ROVER        174
# SATURN            156
# RAM               153
# MASERATI          125
# BENTLEY           118
# LAMBORGHINI       111
# ASTON MARTIN      106
# ROLLS-ROYCE       106
# FIAT               85
# FERRARI            73
# ...

# %%
data[(data["MAKE"] == "BMW") & (data["CYLINDERS"] == 8)]
# Out:
#        YEAR MAKE             MODEL          VEHICLE CLASS  ENGINE SIZE  \
# 45     2000  BMW              540I                COMPACT          4.4
# 46     2000  BMW              540I                COMPACT          4.4
# 47     2000  BMW      540I TOURING  STATION WAGON - SMALL          4.4
# 48     2000  BMW              740I               MID-SIZE          4.4
# 49     2000  BMW             740IL              FULL-SIZE          4.4
# ...     ...  ...               ...                    ...          ...
# 21723  2022  BMW           X5 M50I          SUV: STANDARD          4.4
# 21725  2022  BMW              X6 M          SUV: STANDARD          4.4
# 21726  2022  BMW  X6 M COMPETITION          SUV: STANDARD          4.4
# 21727  2022  BMW           X6 M50I          SUV: STANDARD          4.4
# 21729  2022  BMW           X7 M50I          SUV: STANDARD          4.4
#
#        CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 KM)  \
# ...

# %%
data[(data["MAKE"] == "BMW")]["CYLINDERS"].value_counts()
# Out:
# CYLINDERS
# 6     883
# 8     369
# 4     191
# 10     25
# 12     22
# Name: count, dtype: int64

# %%
data[["FUEL","EMISSIONS"]].groupby("FUEL").mean()
# Out:
#        EMISSIONS
# FUEL
# D     230.305732
# E     270.578898
# N     312.848485
# X     240.280748
# Z     260.574818

# %% [markdown]
# ## Scelta una marca contare quanti tipologie di veicolo

# %%
data[data["MAKE"] == "VOLVO"]["VEHICLE CLASS"].value_counts()
# Out:
# VEHICLE CLASS
# COMPACT                     177
# STATION WAGON - MID-SIZE     66
# STATION WAGON - SMALL        56
# SUV                          55
# MID-SIZE                     52
# SUV - SMALL                  30
# SUBCOMPACT                   22
# SUV: SMALL                   18
# STATION WAGON: SMALL         15
# SUV: STANDARD                10
# SUV - STANDARD                8
# STATION WAGON: MID-SIZE       6
# Name: count, dtype: int64

# %%
audi_bmw = (data["MAKE"] == "AUDI") | (data["MAKE"] == "BMW")
data[audi_bmw][["MAKE","CYLINDERS","EMISSIONS"]].groupby(["MAKE","CYLINDERS"]).mean()
# Out:
#                  EMISSIONS
# MAKE CYLINDERS
# AUDI 4          209.636076
#      5          241.666667
#      6          249.483271
#      8          292.469136
#      10         337.682927
#      12         319.750000
# BMW  4          202.361257
#      6          237.628539
#      8          295.701897
#      10         358.400000
#      12         323.590909

# %%
consMarca = data[["MAKE", "FUEL CONSUMPTION"]].groupby("MAKE").mean()
consMarca
# Out:
#                FUEL CONSUMPTION
# MAKE
# ACURA                 10.937652
# ALFA ROMEO            11.104762
# ASTON MARTIN          17.026415
# AUDI                  12.496894
# BENTLEY               19.685593
# BMW                   12.730537
# BUGATTI               27.650000
# BUICK                 12.182051
# CADILLAC              13.696313
# CHEVROLET             14.352019
# CHRYSLER              12.698824
# DAEWOO                10.535294
# DODGE                 15.147459
# FERRARI               21.683562
# FIAT                   8.842353
# FORD                  13.569026
# GENESIS               13.495238
# GMC                   16.188357
# HONDA                  9.381640
# HUMMER                16.390476
# HYUNDAI               10.052941
# INFINITI              12.596071
# ISUZU                 14.888889
# JAGUAR                13.376374
# JEEP                  12.529963
# KIA                   10.142669
# LAMBORGHINI           21.001802
# LAND ROVER            15.174713
# ...

# %%
type(consMarca)
# Out:
# pandas.core.frame.DataFrame

# %%
type(consMarca.values)
# Out:
# numpy.ndarray

# %%
consMarca.to_numpy()
# Out:
# array([[10.93765182],
#        [11.1047619 ],
#        [17.02641509],
#        [12.49689441],
#        [19.68559322],
#        [12.73053691],
#        [27.65      ],
#        [12.18205128],
#        [13.69631336],
#        [14.35201878],
#        [12.69882353],
#        [10.53529412],
#        [15.14745946],
#        [21.68356164],
#        [ 8.84235294],
#        [13.56902552],
#        [13.4952381 ],
#        [16.18835667],
#        [ 9.38163993],
