# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataComuni = pd.read_csv("regpie-Asco_siti_contaminati_6051-all.csv", sep=";")
dataComuni
# Out:
#              prov             comune  id_sito codice_regionale  \
# 0     ALESSANDRIA  CARBONARA SCRIVIA     2755         01-02755
# 1     ALESSANDRIA           CARTOSIO      626         01-00626
# 2     ALESSANDRIA  CASALE MONFERRATO        2         01-00002
# 3     ALESSANDRIA  CASALE MONFERRATO      749         01-00749
# 4     ALESSANDRIA  CASALE MONFERRATO     1041         01-01041
# ...           ...                ...      ...              ...
# 1271     VERCELLI         VILLARBOIT     1019         01-01019
# 1272     VERCELLI         VILLARBOIT     1394         01-01394
# 1273     VERCELLI         VILLARBOIT     1439         01-01439
# 1274     VERCELLI         VILLARBOIT     1449         01-01449
# 1275     VERCELLI         VILLARBOIT     1508         01-01508
#
#      codice_provinciale                                              cause  \
# 0              AL-00267  Presenza di sostanze inquinanti dovuta a gesti...
# ...

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax.hist(dataComuni["prov"], edgecolor="black", bins=len(dataComuni["prov"].unique()))
ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=45, ha='right')
plt.show()

# %%
attivi = dataComuni[dataComuni["stato_procedimento"] == "ATTIVO"]["prov"]
conclusi = dataComuni[dataComuni["stato_procedimento"] == "CONCLUSO"]["prov"]

fig, ax = plt.subplots(figsize=(10,4))

ax.hist(attivi, edgecolor="black", bins = len(dataComuni["prov"].unique()), color = "red", alpha = 0.5)
ax.hist(conclusi, edgecolor="black", bins = len(dataComuni["prov"].unique()), color = "green", alpha = 0.5)
ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=45, ha='right')

ax.set_title("siti contaminati attivi e bonificati per provincia")
ax.legend(["attivi", "bonificati"])
ax.set_ylabel("numero di siti")
fig.set_facecolor("lightgrey")
plt.show()
