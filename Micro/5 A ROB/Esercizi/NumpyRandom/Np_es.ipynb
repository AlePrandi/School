# %% [markdown]
# # Funzioni matematiche

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array = np.array([0.,1.,4.,6.])

# %% [markdown]
# Calcoliamo l'esponenziale dell'array con la funzione $e^x$. Questo tra `$` è un esempio di `MathText`.
#
# Per esempio in *MathText* posso scrivere le frazioni $\frac{3}{2}$

# %%
np.exp(array)
# Out:
# array([  1.        ,   2.71828183,  54.59815003, 403.42879349])

# %%
x = np.linspace(-5,5,400) #400 valori equispaziati tra -5 e 5
y = np.exp(x)
plt.plot(y)

# %%
x = np.linspace(0, 4*np.pi, 400)
y = np.sin(x)
plt.plot(y)

# %%
y[y > 0.5] = 0.5
plt.plot(x,y)

# %%
x = np.linspace(-20*np.pi, 20*np.pi, 1000)
y = np.sin(x)/x
plt.plot(x,y)

# %%
x = np.linspace(-5,5, 1000)
y = np.exp(-x**2) #distribuzione gaussiana
plt.plot(x,y)

# %% [markdown]
# La distribuzione gausssiana è data da 2 parametri:
#
# 1. La media `m` che è data dal valore massimo
# 2. La deviazione standard `s` che è data dalla larghezza

# %% [markdown]
# ## Esercizio

# %% [markdown]
# ### Generazione numeri pseudo casuali usando la distribuzione gaussiana usando `np.random.normal()`

# %%
n_persone = 20
media = 175
altezze_cm = np.random.normal(media, 8, n_persone) # random.normal genera numeri usando una distribuzione gaussiana
np.round(altezze_cm, 1)
# Out:
# array([172.7, 177.8, 162.6, 156.1, 163.9, 165.3, 181.9, 179. , 167.7,
#        177.3, 161.6, 168.4, 164.1, 192.1, 170.4, 176.9, 186.2, 177. ,
#        171.9, 169.4])

# %% [markdown]
# ### Estraiamo in maniera pseudo-casuale elementi da un array con la funzione `np.random.choice()`

# %%
Moneta = np.array(["Testa", "Croce"]) #array di stringhe
prob = np.array([0.7,0.3])
np.random.choice(Moneta, 10, p = prob)
# Out:
# array(['Testa', 'Testa', 'Testa', 'Croce', 'Testa', 'Testa', 'Croce',
#        'Testa', 'Testa', 'Testa'], dtype='<U5')
