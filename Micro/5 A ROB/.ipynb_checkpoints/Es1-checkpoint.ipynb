# %% [markdown]
# # Esercizio 1

# %% [markdown]
# ### FUNZIONI PER CALCOLARE N-GRAMMI

# %%
def create_ngram(your_list):
    text = "".join(your_list)
    n = int(input("inserisci il numero di lettere per ogni combinazione: ")) 
    cont_comb = {}
    for pos in range(0,len(text) - n):
            combinazione = element[pos:pos+n]
            if combinazione in cont_comb:
                cont_comb[combinazione] += 1
            else:
                cont_comb[combinazione] = 1
    return cont_comb

# %%
def possible_successor(your_list):
    text = "".join(your_list)
    n = 2
    diz_comb = {}
    for pos in range(0,len(text) - n):
            combinazione = element[pos:pos+n]
            next = 
            if c in combinazione:
                diz_comb[combinazione].append(pos + n)
            else:
                cont_comb[combinazione] = 
    return cont_comb

# %%
righe = []
with open("./OSCAR_WILDE_Il_fantasma_di_Canterville.txt", 'r') as file:
        righe = {riga for riga in file.readlines() if len(riga) > 1}

print(len(righe))
# Out:
# 2485

# %%
n_char = 0
max_len = ""
for element in righe:
    if len(element) > len(max_len):
        max_len = element
    n_char += len(element)

print(n_char)
print(max_len)
# Out:
# 150841
# â€” SÃ¬, signora, â€” rispose la governante. â€” Vi Ã¨ stato versato del sangue.

# %%
for element in righe:
    print(element[0])
# Out:
# b
# P
# e
# s
# A
# g
# p
# S
# b
# O
# r
# a
# t
# O
# M
# l
# e
# c
# g
# s
# â
# n
# s
# A
# n
#
# d
# S
# â
# s
# l
# d
# V
# u
# E
# q
# E
# s
# l
# p
# q
# q
# D
# i
# â
# S
# v
# e
# t
# a
# a
# â
# i
# M
# N
# â
# A
# d
# v
# a
# P
# s
# t
# A
# v
# d
# I
# s
# c
# L
# l
# l
# m
# W
# â
# l
# P
# u
# s
# p
# a
# â
# m
# â
# a
# c
# B
# T
# m
# V
# t
# p
# N
# a
# U
# o
# c
# Y
# G
# m
# s
# I
# c
# c
# d
# q
# o
# s
# f
# f
# I
# e
# f
# e
# c
# d
# d
# p
# S
# V
# v
# f
# m
# s
# Q
# g
# s
# p
# g
# t
# l
# g
# â
# s
# â
# l
# f
# t
# â
# u
# p
# s
# P
# m
# b
# s
# u
# L
# S
# I
# A
# V
# b
# A
# a
# o
# d
# r
# d
# D
# S
# c
# m
# s
# s
# a
# M
# b
# i
#
# r
# l
# g
# d
# m
# m
# f
# m
# e
# d
# d
# a
# c
# i
# c
# p
# q
# a
# e
# R
# t
# a
# e
# p
# I
# â
# e
# Q
# q
# â
# S
# d
# d
# c
# q
# f
# s
# s
# i
# r
# F
# r
# n
#
# p
# c
# p
# l
# u
# b
# p
# D
# r
# Q
# â
# s
# P
# s
# p
# f
# i
# u
# R
# d
# l
# i
# F
# N
# I
# a
# n
# d
# T
# H
# l
# u
# a
# e
# f
# G
# d
# l
# F
# c
# p
# s
# c
# d
# v
# d
# â
# i
# s
# m
# c
# â
# C
# a
# I
# I
# n
# M
# e
# â
# s
# R
# s
# p
# p
# P
# â
# v
# â
# â
# c
# g
# m
# c
# u
# R
# S
# T
# L
# i
# p
# q
# Ã
# z
# a
# â
# A
# g
# r
# f
# h
# â
# c
# â
# V
# P
# t
# r
# â
# b
# a
# b
# g
# L
# f
# E
# g
# d
# s
# s
# I
# s
# i
# p
# s
# C
# Q
# p
# l
# S
# c
# d
# l
# v
# d
# R
# N
# t
# c
# V
# s
# v
# A
# r
# s
# U
# l
# u
# q
# c
# S
# c
# S
#
# S
# T
# t
# m
# p
# p
# M
# t
# S
# f
# I
# l
# â
# b
# i
# S
# P
# a
# V
# d
# c
# â
# c
# s
# N
# i
# a
# â
# p
# C
# c
# E
# g
# b
# v
# e
# e
# a
# a
# d
# â
# g
# â
# d
# l
#
# â
# p
# c
# i
# p
# i
# N
# S
# I
# â
# g
# p
#
# a
# C
# l
# s
# d
# S
# a
# â
# i
# p
# m
#
# d
# i
# t
# p
# s
# V
# p
# Â
# i
# v
# f
# n
# W
# l
# â
# d
# S
# s
# v
# d
# p
# I
# H
# â
# M
# c
# â
# m
# r
# p
# f
# â
# d
# c
# m
# i
# â
# i
# s
# L
# c
# a
# e
# c
# p
# A
# q
# n
# p
# s
# S
# p
# Q
# u
# b
# p
# I
# S
# p
# _
# C
# l
# g
# T
# e
# S
# P
# a
# c
# U
# â
# l
# â
# v
# u
# â
# c
# p
# E
# â
# l
# â
# C
# s
# m
# a
# A
# n
# N
# a
# i
# â
# â
# t
# V
# s
# g
# Â
# o
# c
# l
# s
# i
# p
# q
# b
# t
# â
# c
# v
# M
# i
# s
# N
# M
# m
# _
# l
# P
# e
# n
# I
# E
#
# Q
# â
# d
# c
# l
# c
# L
# a
# b
# V
# c
# u
# v
# c
# p
# l
# u
# s
# f
# d
# l
# d
# L
# A
# i
# c
# c
# r
# C
# s
# u
# c
# n
# g
# v
# m
# s
# M
# a
# D
# g
# i
# N
# s
# C
# c
# U
# c
# n
# s
# P
# f
# f
# p
# d
# g
# Â
# E
# s
# L
# E
# â
# i
# c
# P
# L
# â
# I
# i
# f
# d
# l
# â
# M
# T
# c
# v
# b
# a
# n
# i
# L
# d
# i
# C
# d
# a
# I
# _
# E
# l
# i
# n
# P
# n
# R
# e
# g
# d
# c
# N
# V
# L
# s
# Ã
# e
# a
# Ã
# V
# â
# N
# I
# L
# â
# M
# l
# g
# l
# P
# m
# d
# M
# A
# i
# P
# g
# p
# P
# I
# â
# c
# d
# f
# M
# I
# T
# a
# n
# D
# l
# g
#
# â
# v
# n
# s
# s
# t
# d
# c
# p
# a
# l
# n
# c
# d
# d
# d
# S
# A
# o
# p
# L
# L
# c
# m
# c
# u
# d
# p
# s
# C
# H
# G
# q
# â
# u
#
# s
# D
# â
# i
# m
# t
# â
# E
# p
# p
# i
# â
# z
# F
# L
# s
# M
# m
# t
# P
# s
# e
# s
# c
# t
# â
# d
# d
# p
# e
# g
# e
# T
# F
# c
# p
# S
# â
# p
# M
# l
# z
# a
# S
# Â
# e
# m
# p
# d
# d
# L
# â
# m
# i
# M
# A
# s
# s
# e
#
# d
# p
# I
# L
# a
# â
# â
# u
# f
# s
# I
# c
# s
# E
# l
# s
# f
# l
# s
# i
# â
# M
# A
# L
# s
# d
# D
# d
# d
# â
# â
# p
# P
# a
# b
# n
# L
# C
# c
# c
# l
# e
# b
# n
# L
# s
# N
# a
# W
# E
# s
# r
# c
# â
# â
# L
# s
# v
# p
# c
# a
# p
# D
# l
# â
# I
# n
# m
# a
# â
# d
# â
# c
# d
# E
# C
# q
# s
# s
# c
# g
# f
# d
# u
# S
# n
# â
# I
# i
# S
# c
# p
# p
# a
# L
# V
# S
# l
# d
# L
# e
# q
# I
# a
# a
# c
# M
# e
# m
# t
# s
# l
# p
# E
# â
# P
# g
# v
# M
# f
# Â
# S
# u
# I
# c
# u
# r
# l
# t
# â
# i
# d
# c
# s
# u
# E
# p
# s
# s
# r
# c
# d
# L
# p
# r
# a
# s
# â
# t
# â
# L
# â
# â
# c
# s
# G
# d
# â
# g
# Â
# S
# q
# B
# m
# â
# â
# s
# s
# p
# p
# q
# i
# d
# s
# t
# d
# c
# A
# c
# s
# R
# I
# O
# f
# g
# S
# b
# U
# n
# E
# d
# f
# l
# g
# A
# p
# s
# e
# p
# S
# q
# a
# L
# â
# d
# u
# m
# n
# b
# â
# d
# c
# d
# m
# J
# L
# s
# p
# L
# M
# e
# l
# s
# l
# p
# v
# e
# M
# P
# U
# d
# c
# u
# F
# a
# D
# q
# s
# m
# p
# s
# s
# U
# F
# L
# p
# b
# d
# W
# o
# P
# e
# l
# c
# L
# r
# d
# i
# l
# A
# d
# c
# D
# L
# s
# P
# e
# s
# s
# â
# c
# l
# D
# p
# p
# d
# o
# i
# S
# g
# p
# f
# â
# Q
# R
# s
# C
# H
# n
# I
# d
# v
# â
# P
# M
# I
# m
# s
# S
# S
# N
# â
# L
# L
#
# l
# v
# Q
# p
# i
# s
# C
# Q
# g
# n
# d
# i
# â
# a
# P
# m
# p
# c
# S
# i
# Q
# E
# A
# p
# e
# â
# C
#
# c
# m
# â
# l
# c
# d
# p
# a
# v
# S
# L
# â
# o
# s
# d
# c
# f
# I
# n
# a
# f
# m
# â
# v
# a
# v
# i
# Â
# e
# p
# a
# V
# e
# â
# d
# t
# d
# t
# â
# n
# d
# i
# p
# s
# u
# p
# a
# p
# d
# l
# i
# p
# Q
# c
# L
#
# I
# i
# t
# I
# f
# v
# l
# â
# s
# M
# â
# i
# d
# d
# n
# L
# A
# t
# l
# i
# t
# s
# Q
# F
# b
# L
# c
# d
# f
# s
# U
# Q
# s
# N
# M
# S
#
# i
# c
# N
# c
# c
# â
# P
# n
# u
# p
# U
# i
# a
# L
# s
# c
# f
# d
# t
# p
# s
# s
# c
# D
# r
# D
# t
# â
# l
# â
# e
# D
# n
# e
# t
# f
# a
# â
# e
# m
# E
# n
# a
# d
# a
# E
# d
# d
# â
# c
# m
# â
# s
# n
# t
# i
# c
# I
# c
# d
# D
# m
# c
# c
# L
# U
# â
# T
# â
# l
# i
# v
# d
# d
# d
# C
# p
# â
# â
# A
# p
# f
# u
# l
# o
# â
# m
# s
# R
# p
# f
# I
# l
# m
# u
# H
# S
# M
# f
# l
# a
# c
# e
# N
# L
# Â
# d
# d
# c
# p
# v
# I
# v
# i
# s
# â
# N
# d
# v
# d
# s
# s
# â
# s
# a
# a
# â
# N
# â
# p
# â
# s
# s
# C
# l
# s
# l
# d
# A
# Â
# u
# P
# C
# m
# a
# c
# f
# R
# L
# i
# i
# s
# n
# S
# â
# c
# l
# D
# L
# c
# b
# s
# P
# g
# r
# C
# p
# t
# D
# Q
# m
# s
# a
# g
# A
# s
# o
# g
# c
# g
# g
# I
# p
# L
# c
# â
# s
# p
# A
# e
# p
# r
# e
# M
# e
# s
# p
# L
# â
# â
# l
# p
# N
# P
# L
# M
# v
# p
# E
# p
# d
# a
# d
# r
# d
# l
# p
# q
# â
# c
# l
# D
# q
# M
# â
# m
# A
# s
# â
# s
# V
# c
# l
# L
# n
# d
# c
# a
# m
# p
# G
# l
# v
# a
# a
# a
# L
# â
# d
# p
# v
# â
# s
# s
# c
# G
# l
# f
# i
# e
# A
# a
# â
# p
# N
# L
# c
# q
# L
# e
# c
# â
# s
# l
# A
# N
# g
# C
# E
# I
# g
# a
# a
# B
# r
# c
# m
#
# o
# â
# I
# p
# p
# s
# P
# s
# d
# a
# G
# â
# â
# d
# â
# c
# Q
# s
# u
# U
# d
# i
# p
# i
# s
# f
# P
# s
# L
# M
# m
#
# S
# l
# a
# Q
# n
# A
# e
# C
# s
# d
# â
# f
# e
# e
# E
# L
# Ã
# d
# m
# L
# â
# D
# â
# i
# A
# r
# I
#
# i
# Â
# I
# Q
# s
# â
# r
# s
# â
# d
# s
# r
# u
# c
# u
# A
# l
# â
# m
# Q
# p
# S
# Q
# g
# c
# d
# â
# Â
# c
# E
# c
# Q
#
# p
# o
# S
# s
# s
# c
# I
# a
# u
# v
# d
# f
# u
# g
# d
# â
# s
# s
# S
# i
# L
# s
# g
# â
# i
# D
# g
# g
# c
# s
# t
# â
# n
# V
# n
# f
# r
# â
# p
# d
# d
# e
# D
# â
# t
# O
# s
# l
# a
# c
# N
# â
# r
# t
# L
# g
# e
# r
# i
# l
# T
# W
# i
# â
# m
# â
# S
# c
# m
# t
# I
# s
# d
# s
# a
# G
# I
# E
# i
# a
# p
# e
# l
# â
# f
# s
# m
# p
# g
# v
# T
# Â
# I
# â
# a
# c
# Â
# L
# â
# T
# a
# t
# d
# E
# â
# v
# u
# Q
# O
# M
# c
# l
# I
# p
# p
# b
# d
# s
# e
# d
# P
# n
# â
# â
# p
# â
# d
# S
#
# t
# b
# e
# b
# t
# L
#
# m
# f
# f
# E
# â
# a
# b
# a
# C
# s
# d
# l
# d
# I
# q
# c
# A
# n
# M
# V
# o
# W
# â
# Â
# S
# f
# L
# u
# s
# I
# i
# i
# I
# v
# d
# v
# â
# t
# u
# r
# e
# â
# q
# n
# v
# S
# P
# s
# p
# G
# L
# A
# I
# l
# s
# p
# s
# p
# â
# s
# E
# u
# p
# v
# Q
# p
# g
# g
# L
# f
# d
# A
# d
# s
# L
# g
# Ã
# n
# E
# p
# u
# l
# q
# l
# P
# l
# g
# â
# o
# s
# â
# p
# Â
# p
# b
# i
# t
# Q
# I
# v
# G
# l
# o
# c
# v
# V
# â
# c
# â
# â
# s
# p
# d
# E
# â
# s
# M
# u
# t
# d
# D
# s
# s
# e
# â
# I
# M
# L
# â
# â
# s
# l
# v
# i
# m
#
# q
# d
# s
# d
# e
# p
# t
# c
# s
# â
# A
# e
# â
# c
# p
# S
# e
# d
# g
# s
# c
# r
# i
# c
# â
# d
# L
# I
# s
# L
# D
# t
# d
# f
# d
# l
# p
# c
# F
# s
# â
# l
# d
# p
# a
#
# f
# g
# D
# d
# a
# F
# b
# m
# L
# a
# d
# t
# â
# l
# m
# o
# p
# v
# l
# p
# n
# D
# a
# L
# d
# s
# D
# n
# t
# p
# s
# â
# I
# p
# v
# P
# c
# u
# s
# c
# L
# s
# d
# s
# a
# â
# D
# s
# a
# S
# s
# f
# L
# r
# t
# s
# d
# d
# s
# â
# s
# i
# e
# g
# r
# g
# â
# U
# l
# f
# d
# C
# o
# e
# l
# E
# c
# v
# s
# I
# s
# d
# a
# c
# p
# s
# s
# L
# U
# r
# s
# Â
# r
# b
# E
# A
# E
# â
# G
# d
# â
# c
# a
# i
# e
# C
# a
# P
# d
# T
# â
# s
# E
# I
# m
# p
# l
# e
# i
# D
# l
# D
# p
# f
# Q
# i
# i
# b
# S
# t
# â
# a
# m
# a
# M
# â
# a
# i
# p
# â
# Q
# s
# n
# p
# g
# L
# d
# s
# c
# â
# W
# s
# A
# p
# a
# s
# â
# c
# b
# c
# p
# m
# P
# u
# l
# t
# V
# n
# l
# B
# e
# p
#
# G
# m
# f
# m
# Q
# u
# â
# E
# s
# â
# D
# S
# c
# c
# g
# B
# L
# e
# H
# e
# T
# m
# i
# l
# m
# u
# â
# m
# V
#
# B
# a
# â
# â
# M
# â
# i
# U
# m
# P
# Â
# â
# c
# â
# c
# a
# r
# s
# â
# F
# a
# C
# a
# m
# p
# l
# E
# d
# f
# s
# P
# a
# c
# a
# s
# â
# u
# â
# Q
# n
# i
# L
# A
# â
# Q
# n
# u
# e
# l
# Q
# r
# l
# l
# c
# R
# a
# I
# a
# I
# P
# L
# S
# â
# i
# S
# E
# s
# s
# b
# d
# s
# f
# S
# p
# â
# g
# d
# â
# n
# Q
# â
# s
# i
# e
# p
# P
# e
# M
# p
# t
# L
# s
# s
# p
# v
# p
# I
# G
# p
# M
# i
# A
# P
# a
# e
# u
# b
# e
# n
# a
# T
# â
# a
# f
# a
# D
# Q
# t
# s
# â
# g
# s
# S
# D
# e
# â
# s
# d
# d
# m
# I
# c
# m
#
# â
# I
# N
# s
# L
# â
# d
# c
# p
# S
# d
# E
# b
# r
# M
# a
# c
# l
# I
# c
# v
# g
# c
# e
# L
# â
# p
# s
# â
# i
# â
# u
# s
# G
# h
# i
# q
# A
# s
# â
# I
# a
# o
# r
#
# a
# R
# L
# u
# s
# t
# c
# p
# I
# s
# â
# l
# P
# â
# P
# W
# a
#
# m
# d
# g
# o
# I
# c
# p
# g
# d
# Q
# s
# p
# â
# i
# p
# E
# â
# I
# s
# n
# n
# W
# c
# q
# â
# â
# i
# p
# p
# v
# b
# â
# i
# r
# Q
# p
#
# s
# A
# c
# f
# P
# l
# d
# u
# E
# p
# p
# v
# s
# C
# G
# e
# d
# W
# a
# p
# p
# Â
# s
# e
# s
# p
# d
# c
# s
# v
# Â
# c
# l
# l
# v
# f
# a
# P
# L
# c
# S
# e
# v
# p
# u
# E
# d
# i
# s
# A
# q
# S
# c
# l
# b
# r
# n
# L
# D
# t
# i
# A
# s
# N
# s
# d
# m
# m
# Q
# I
# P
# s
# u
# h
# f
# L
# I
# s
# p
# s
# d
# U
# p
# â
# a
# S
# d
# p
# e
# E
# l
# r
# c
# p
# s
# p
# M
# Â
# l
# R
# F
# c
# u
# d
# d
# T
# l
# d
# L
# b
# d
# L
# n
# c
# v
# m
# E
# â
# p
# u
# a
# d
# â
# m
# i
# c
# n
# t
# L
# L
# g
# c

# %%
cont_lettere = {}
for element in righe:
    for c in element:
        if c in cont_lettere:
            cont_lettere[c] += 1
        else:
            cont_lettere[c] = 1
print(cont_lettere)
# Out:
# {'b': 1082, 'i': 11825, 's': 6489, 'o': 10717, 'g': 2276, 'n': 7871, ' ': 22526, 'd': 4546, 'u': 3836, 'r': 8020, 'l': 7461, 'e': 13713, 'p': 2925, 'v': 2628, '.': 1376, '\n': 2484, 'P': 146, "'": 483, 't': 7010, 'a': 13041, 'm': 3030, 'f': 1276, 'c': 4909, ':': 133, 'h': 1262, ',': 1751, 'S': 241, '!': 99, ';': 160, 'Ã': 1168, '¬': 146, 'C': 197, 'A': 240, '²': 414, 'U': 48, '\xa0': 200, 'E': 158, 'G': 76, 'H': 31, 'y': 121, 'L': 194, '¹': 129, 'O': 104, 'q': 496, 'z': 821, 'V': 130, 'M': 127, '¨': 235, '?': 71, 'â': 383, '€': 384, '”': 383, 'I': 195, 'N': 115, 'R': 70, 'Y': 7, 'Â': 90, '»': 45, 'x': 6, 'k': 42, 'T': 78, 'W': 72, 'D': 85, 'B': 51, 'ˆ': 23, '©': 7, '®': 6, '_': 116, '-': 33, 'F': 43, '«': 45, 'Q': 54, 'w': 15, 'Z': 7, 'K': 6, '¼': 2, 'J': 9, '1': 9, '´': 1, '7': 7, '*': 3, 'ª': 3, '5': 5, '4': 2, 'X': 1, '9': 2, '2': 3, '0': 2, 'j': 2, '6': 3, 'Å': 1, '“': 1, '¦': 1, '8': 1}

# %% [markdown]
# # ES CON FUNZIONI

# %%
text = "".join(righe)
#create_gram(righe)
print(possible_successor(righe))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 3
#       1 text = "".join(righe)
#       2 #create_gram(righe)
# ----> 3 print(possible_successor(righe))
#
# Cell In[4], line 8, in possible_successor(your_list)
#       6 combinazione = element[pos:pos+n]
#       7 if c in combinazione:
# ----> 8     cont_comb[combinazione].append(pos + n)
#       9 else:
#      10     cont_comb[combinazione] = [c]
#
# KeyError: 'o\n'
