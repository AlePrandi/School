# %% [markdown]
# <center>
# <hr>
# <h1>Basic build and visualization</h1>
# <h2>Programma la tua prima Intelligenza Artificiale</h2>
# <h2>Alessandro Cossard</h2>
# <hr>
# </center>

# %%
#pip3 install networkx

# %%
import networkx as nx
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
G=nx.Graph()

# %%
G.add_nodes_from(['Qui','Quo','Qua','Paperino'])

# %%
G.nodes()
# Out:
# NodeView(('Qui', 'Quo', 'Qua', 'Paperino'))

# %%
G.add_node('Topolino')

print ("I nodi sono " + str(G.nodes()))
# Out:
# I nodi sono ['Qui', 'Quo', 'Qua', 'Paperino', 'Topolino']

# %%
G.add_edges_from([('Qui','Quo'),('Qui','Paperino'),
('Topolino','Qui'),('Quo','Qua'),('Topolino','Paperino')])

# %%
G.add_edge('Qua','Paperino')

print ("I nodi sono " + str(G.nodes()))

print ("I links sono " + str(G.edges()))
# Out:
# I nodi sono ['Qui', 'Quo', 'Qua', 'Paperino', 'Topolino']
# I links sono [('Qui', 'Quo'), ('Qui', 'Paperino'), ('Qui', 'Topolino'), ('Quo', 'Qua'), ('Qua', 'Paperino'), ('Paperino', 'Topolino')]

# %%
print (G.degree('Qui'))
# Out:
# 3

# %%
print (G.degree())
# Out:
# [('Qui', 3), ('Quo', 2), ('Qua', 2), ('Paperino', 3), ('Topolino', 2)]

# %% [markdown]
# # Import the edge file with NetworkX

# %%
H=nx.Graph()

# %%
fh=open('./baboon.edges','r')
#reading all the file lines
for line in fh.readlines():
    #remove "\n" characters (.strip()) and split the line at blank spaces (split.())
    s=line.strip().split()
    if s[0]!='#':
        #the first lines are comments
        origin=int(s[0])
        dest=int(s[1])
        H.add_edge(origin,dest)
    
#chiudo il file
fh.close()

# %%
print ("The network has", len(H), "nodes")
# Out:
# The network has 15 nodes

# %%
print (H.degree())
#this is a dictionary node->degree_in
# Out:
# [(2, 1), (8, 4), (4, 2), (6, 4), (14, 3), (18, 1), (13, 2), (7, 1), (19, 1), (9, 2), (11, 2), (10, 2), (17, 1), (15, 1), (16, 1)]

# %% [markdown]
# ### Visualizzazione

# %%
nx.draw_circular(H)
plt.show()

# %%
nx.draw_random(H)
plt.show()

# %%
nx.draw_spring(H)
plt.show()

# %%
pos=nx.spring_layout(H)
pos
# Out:
# {2: array([-0.26623871,  0.05620133]),
#  8: array([-0.25732552,  0.17228118]),
#  4: array([0.20691617, 0.34888676]),
#  6: array([0.30477553, 0.32562237]),
#  14: array([0.12341359, 0.28669713]),
#  18: array([0.37985212, 0.43602164]),
#  13: array([0.4621529 , 0.27323837]),
#  7: array([0.58539626, 0.23180633]),
#  19: array([-0.33186883,  0.2751844 ]),
#  9: array([-0.0667967 ,  0.22913936]),
#  11: array([-0.41809046,  0.11477552]),
#  10: array([-0.04513292, -0.89980601]),
#  17: array([-0.14484063, -0.92604146]),
#  15: array([ 0.01237604, -1.        ]),
#  16: array([-0.54458886,  0.07599307])}

# %%
nx.draw_networkx_nodes(H, pos)

# %%
pos2=nx.spring_layout(H, scale=2.0)
pos2
# Out:
# {2: array([-0.57124349,  0.38458209]),
#  8: array([-0.36430646,  0.13735596]),
#  4: array([-0.57927447, -0.90861757]),
#  6: array([-0.3154813 , -0.98230727]),
#  14: array([-0.50269319, -0.65610065]),
#  18: array([-0.39207844, -1.30563404]),
#  13: array([ 0.08396418, -0.97570613]),
#  7: array([ 0.39649308, -1.03248469]),
#  19: array([-0.21909906,  0.42695729]),
#  9: array([-0.50548287, -0.24466827]),
#  11: array([-0.06869614, -0.02622632]),
#  10: array([1.01009569, 1.85256074]),
#  17: array([0.81878376, 2.        ]),
#  15: array([1.10883086, 1.6237218 ]),
#  16: array([ 0.10018785, -0.29343294])}

# %%
nx.draw_networkx_nodes(H, pos2)
plt.axis('off')
# Out:
# (-0.6636797413020832,
#  1.1932361228682575,
#  -1.4709157433636846,
#  2.1652817020649375)

# %%
s=nx.draw_networkx_nodes(H,
            pos2,
            node_size=70.0,
            node_color=[H.degree(v) for v in H],
            alpha=0.8,#colore pieno
            cmap=plt.cm.jet #mappa colore di tipo "jet"
            )

#nx.draw_networkx_edges(BA,pos2)

#mostro la legenda con i colori corrispondenti al degree
plt.colorbar(s)
plt.axis('off')
plt.show()

# %%
nx.draw_networkx_nodes(H,
            pos2,
            node_color=[H.degree(v) for v in H],
            node_size=[25*H.degree(v) for v in H],
            alpha=1.0,#colore pieno
            cmap=plt.cm.jet #mappa colore di tipo "jet"
            )

nx.draw_networkx_edges(H,pos2)

#mostro la legenda con i colori corrispondenti al degree
cbar=plt.colorbar(s)
cbar.ax.set_ylabel('Degree')
plt.show()
# Out:
# /var/folders/6r/15rwhds13s3ghcz0rf3cmv0r0000gn/T/ipykernel_91125/3601251149.py:12: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   cbar=plt.colorbar(s)
